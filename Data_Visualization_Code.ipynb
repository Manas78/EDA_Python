# %% [markdown]
# # Data Importing

# %%
import pandas as pd
bank_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day3_Files/Datasets/bank-full.csv")
print(bank_data.shape)
#https://archive.ics.uci.edu/ml/datasets/Bank+Marketing/
# Out:
# (45211, 1)

# %%
bank_data.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  58;"management";"married";"tertiary";"no";2143...
# 1  44;"technician";"single";"secondary";"no";29;"...
# 2  33;"entrepreneur";"married";"secondary";"no";2...
# 3  47;"blue-collar";"married";"unknown";"no";1506...
# 4  33;"unknown";"single";"unknown";"no";1;"no";"n...

# %%
import pandas as pd
bank_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day3_Files/Datasets/bank-full.csv",sep=';')
print(bank_data.shape)
# Out:
# (45211, 17)

# %%
bank_data.head()
# Out:
#    age           job  marital  education  ... pdays  previous poutcome   y
# 0   58    management  married   tertiary  ...    -1         0  unknown  no
# 1   44    technician   single  secondary  ...    -1         0  unknown  no
# 2   33  entrepreneur  married  secondary  ...    -1         0  unknown  no
# 3   47   blue-collar  married    unknown  ...    -1         0  unknown  no
# 4   33       unknown   single    unknown  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %%
bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# # Continuous variable distributions

# %% [markdown]
# ## Box Plots

# %%
import matplotlib.pyplot as plt 
plt.boxplot(bank_data["balance"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f082ccf44a8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f082ccf4eb8>,
#   <matplotlib.lines.Line2D at 0x7f082cd0b278>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f082cd0b978>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f082cd0b5f8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f082ccf47b8>,
#   <matplotlib.lines.Line2D at 0x7f082ccf4b38>]}

# %%
import matplotlib.pyplot as plt 
plt.boxplot(bank_data["age"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f082c8425f8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f082c84e048>,
#   <matplotlib.lines.Line2D at 0x7f082c84e3c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f082c84eac8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f082c84e748>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f082c842908>,
#   <matplotlib.lines.Line2D at 0x7f082c842c88>]}

# %%
plt.boxplot(bank_data["age"], whis= 2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f082c85b400>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f082c8425c0>,
#   <matplotlib.lines.Line2D at 0x7f082c806978>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f082c7fdc50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f082c7fd978>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f082c7f6048>,
#   <matplotlib.lines.Line2D at 0x7f082c7f6518>]}

# %% [markdown]
# ## Histograms

# %%
import seaborn as sns
sns.distplot(bank_data["age"])
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import seaborn as sns
sns.distplot(bank_data["age"],kde=False)

# %%
import seaborn as sns
sns.distplot(bank_data["balance"])

# %%
numeric_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["int64","float64"]]
print(numeric_cols)
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
plt.figure()
for col in numeric_cols:
  sns.distplot(bank_data[col])
  plt.title([col + " Histogram"])
  plt.show()

# %%
plt.figure()
for col in numeric_cols:
  sns.distplot(bank_data[col])
  plt.title([col + " Histogram"])
  plt.show()

# %% [markdown]
# ## Categorical Variables Summary

# %% [markdown]
# ## Bar Charts

# %%
plt.figure()
sns.countplot(x="job",  data=bank_data)

# %%
plt.figure()
sns.countplot(y="job",  data=bank_data)

# %%
categorical_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["object"]]
print(categorical_cols)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

# %%
plt.figure()
for col in categorical_cols:
  sns.countplot(y=col,  data=bank_data)
  plt.title([col + " Bar plot"])
  plt.show()

# %% [markdown]
# # Continuous vs Continuous

# %% [markdown]
# ## Scatter Plots

# %%
bank_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="age", y="balance", data=bank_data)

# %%
sns.scatterplot(x="age", y="balance", hue="y", data=bank_data)

# %%
sns.scatterplot(x="age", y="balance", hue="y", data=bank_data[bank_data["balance"]<20000])

# %% [markdown]
# # Continuous vs Categorical

# %% [markdown]
# ## Histogram overlay

# %%
sns.distplot(bank_data[bank_data["y"]=="no"]["age"], color="red")
sns.distplot(bank_data[bank_data["y"]=="yes"]["age"], color="green")

# %%
plt.figure()
for col in numeric_cols:
  sns.distplot(bank_data[bank_data["y"]=="no"][col], color="red")
  sns.distplot(bank_data[bank_data["y"]=="yes"][col], color="green")
  plt.title([col + " Histogram"])
  plt.show()

# %% [markdown]
# ## Box Plots for Continuous and Categories comparison

# %%
sns.boxplot( x=bank_data["y"], y=bank_data["age"])
plt.title('Age vs y', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Age vs y')

# %%
numeric_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["int64","float64"]]
print(numeric_cols)

for col in numeric_cols:
  sns.boxplot( x=bank_data["y"], y=bank_data[col])
  plt.title([col, "vs y"], fontsize=20)
  plt.show()
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %% [markdown]
# ## Violin plots for Continuous and Categories comparison

# %%
sns.violinplot( x=bank_data["y"], y=bank_data["age"])
plt.title('Age vs y', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Age vs y')

# %%
numeric_cols=[col for col in bank_data.columns if bank_data[col].dtypes in ["int64","float64"]]
print(numeric_cols)

for col in numeric_cols:
  sns.violinplot( x=bank_data["y"], y=bank_data[col])
  plt.title([col, "vs y"], fontsize=20)
  plt.show()
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %% [markdown]
# # Categorical vs Categorical

# %% [markdown]
# ## Bar Chart for categorical variable comparison

# %%
sns.countplot(y="education",  data=bank_data[bank_data["y"]=="no"], color="red")
sns.countplot(y="education",  data=bank_data[bank_data["y"]=="yes"], color="green")

# %%
plt.figure()
for col in categorical_cols:
  sns.countplot(y=col,  data=bank_data[bank_data["y"]=="no"], color="red")
  sns.countplot(y=col,  data=bank_data[bank_data["y"]=="yes"], color="green")
  plt.title([col + " Bar plot"])
  plt.show()

# %%
plt.figure()
for col in categorical_cols:
  sns.countplot(y=col,  data=bank_data,hue="y")
  plt.title([col + " Bar plot"])
  plt.show()

# %% [markdown]
# ## Cross Tables

# %%
for col in categorical_cols:
  print(pd.crosstab(bank_data[col], bank_data['y']))
# Out:
# y                no   yes
# job
# admin.         4540   631
# blue-collar    9024   708
# entrepreneur   1364   123
# housemaid      1131   109
# management     8157  1301
# retired        1748   516
# self-employed  1392   187
# services       3785   369
# student         669   269
# technician     6757   840
# unemployed     1101   202
# unknown         254    34
# y            no   yes
# marital
# divorced   4585   622
# married   24459  2755
# single    10878  1912
# y             no   yes
# education
# primary     6260   591
# secondary  20752  2450
# tertiary   11305  1996
# unknown     1605   252
# y           no   yes
# default
# no       39159  5237
# yes        763    52
# y           no   yes
# housing
# no       16727  3354
# yes      23195  1935
# y        no   yes
# loan
# no    33162  4805
# yes    6760   484
# y             no   yes
# contact
# cellular   24916  4369
# telephone   2516   390
# unknown    12490   530
# y         no  yes
# month
# apr     2355  577
# aug     5559  688
# dec      114  100
# feb     2208  441
# jan     1261  142
# jul     6268  627
# jun     4795  546
# mar      229  248
# may    12841  925
# nov     3567  403
# oct      415  323
# sep      310  269
# y            no   yes
# poutcome
# failure    4283   618
# other      1533   307
# success     533   978
# unknown   33573  3386
# y       no   yes
# y
# no   39922     0
# yes      0  5289

# %%
for col in categorical_cols:
  print(pd.crosstab(bank_data[col], bank_data['y'], margins=True))
  print("============================\n")
# Out:
# y                 no   yes    All
# job
# admin.          4540   631   5171
# blue-collar     9024   708   9732
# entrepreneur    1364   123   1487
# housemaid       1131   109   1240
# management      8157  1301   9458
# retired         1748   516   2264
# self-employed   1392   187   1579
# services        3785   369   4154
# student          669   269    938
# technician      6757   840   7597
# unemployed      1101   202   1303
# unknown          254    34    288
# All            39922  5289  45211
# ============================
#
# y            no   yes    All
# marital
# divorced   4585   622   5207
# married   24459  2755  27214
# single    10878  1912  12790
# All       39922  5289  45211
# ============================
#
# y             no   yes    All
# education
# primary     6260   591   6851
# secondary  20752  2450  23202
# tertiary   11305  1996  13301
# unknown     1605   252   1857
# All        39922  5289  45211
# ============================
#
# y           no   yes    All
# default
# no       39159  5237  44396
# yes        763    52    815
# All      39922  5289  45211
# ============================
#
# y           no   yes    All
# housing
# no       16727  3354  20081
# yes      23195  1935  25130
# All      39922  5289  45211
# ============================
#
# y        no   yes    All
# loan
# no    33162  4805  37967
# yes    6760   484   7244
# All   39922  5289  45211
# ============================
#
# y             no   yes    All
# contact
# cellular   24916  4369  29285
# telephone   2516   390   2906
# unknown    12490   530  13020
# All        39922  5289  45211
# ============================
#
# y         no   yes    All
# month
# apr     2355   577   2932
# aug     5559   688   6247
# dec      114   100    214
# feb     2208   441   2649
# jan     1261   142   1403
# jul     6268   627   6895
# jun     4795   546   5341
# mar      229   248    477
# may    12841   925  13766
# nov     3567   403   3970
# oct      415   323    738
# sep      310   269    579
# All    39922  5289  45211
# ============================
#
# y            no   yes    All
# poutcome
# failure    4283   618   4901
# other      1533   307   1840
# success     533   978   1511
# unknown   33573  3386  36959
# All       39922  5289  45211
# ============================
#
# y       no   yes    All
# y
# no   39922     0  39922
# yes      0  5289   5289
# All  39922  5289  45211
# ============================

# %% [markdown]
# # Pivot table visualization

# %% [markdown]
# ## Heat maps

# %%
pivot=pd.pivot_table(bank_data,values='balance', index=['job'], columns='y')
print(pivot)
sns.heatmap(pivot)
# Out:
# y                       no          yes
# job
# admin.         1093.942070  1437.283677
# blue-collar    1063.402371  1275.420904
# entrepreneur   1494.642229  1818.975610
# housemaid      1353.740053  1793.486239
# management     1703.472723  2140.707917
# retired        1775.685927  2690.627907
# self-employed  1553.418103  2351.807487
# services        985.851783  1112.344173
# student        1347.578475  1488.739777
# technician     1179.842830  1838.152381
# unemployed     1556.144414  1334.257426
# unknown        1710.712598  2232.882353

# %%
pivot=pd.pivot_table(bank_data,values='balance', index=['job'], columns='y')
sns.heatmap(pivot, cmap="YlGnBu")

# %% [markdown]
# ## Groupby

# %%
bank_data.groupby("y")['balance'].mean()
# Out:
# y
# no     1303.714969
# yes    1804.267915
# Name: balance, dtype: float64

# %%
for col in numeric_cols:
  print(bank_data.groupby("y")[col].mean())
  print("============================\n")
# Out:
# y
# no     40.838986
# yes    41.670070
# Name: age, dtype: float64
# ============================
#
# y
# no     1303.714969
# yes    1804.267915
# Name: balance, dtype: float64
# ============================
#
# y
# no     15.892290
# yes    15.158253
# Name: day, dtype: float64
# ============================
#
# y
# no     221.182806
# yes    537.294574
# Name: duration, dtype: float64
# ============================
#
# y
# no     2.846350
# yes    2.141047
# Name: campaign, dtype: float64
# ============================
#
# y
# no     36.421372
# yes    68.702968
# Name: pdays, dtype: float64
# ============================
#
# y
# no     0.502154
# yes    1.170354
# Name: previous, dtype: float64
# ============================
